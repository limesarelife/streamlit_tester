# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import re
import DateTime

# %%
nba = pd.read_csv('archive/NBA.csv',low_memory=False,encoding= 'unicode_escape')
nba['Sport'] = 'Basketball'
nba['League'] = 'NBA'
nba['Country'] = 'USA'
nba.head()
# Out:
#    Year           Team  Wins  Loss  Home Wins  Home Loss  Away Wins
# 0  1968  Atlanta Hawks    48    34         28         12         18  \
# 1  1969  Atlanta Hawks    48    34         25         13         18
# 2  1970  Atlanta Hawks    36    46         21         20         14
# 3  1971  Atlanta Hawks    36    46         22         19         13
# 4  1972  Atlanta Hawks    46    36         28         13         17
#
#    Away Loss   HomePCT   AwayPCT  TotalPCT       Sport League Country
# 0         21  0.700000  0.461538  0.585366  Basketball    NBA     USA
# 1         16  0.657895  0.529412  0.585366  Basketball    NBA     USA
# 2         26  0.512195  0.350000  0.439024  Basketball    NBA     USA
# 3         26  0.536585  0.333333  0.439024  Basketball    NBA     USA
# 4         23  0.682927  0.425000  0.560976  Basketball    NBA     USA

# %%
soccer = pd.read_csv('archive/SoccerLEagues.csv',low_memory=False,encoding= 'unicode_escape')
soccer['Sport'] = 'Soccer'
soccer.drop(columns = ['Season'], inplace = True)
soccer.head()
# Out:
#     Sport  Country           League  Year            Team  Games  HomeWins
# 0  Soccer  Algeria  Algeria-Ligue-1  2010         MC Oran     34        10  \
# 1  Soccer  Algeria  Algeria-Ligue-1  2010  NA Hussein Dey     34         3
# 2  Soccer  Algeria  Algeria-Ligue-1  2011     MC El Eulma     29         9
# 3  Soccer  Algeria  Algeria-Ligue-1  2011          Annaba     29        10
# 4  Soccer  Algeria  Algeria-Ligue-1  2012          Khroub     30         7
#
#    HomeDraw  HomeLoss  HomeRatio  AwayWins  AwayDraw  AwayLoss  AwayGoalsDiff
# 0         5         2         11         0         6        11            -20  \
# 1         5         9         -8         0         5        12            -19
# 2         3         2         13         0         6         9            -19
# 3         5         0         14         0         1        13            -23
# 4         5         3          0         0         5        10            -23
#
#   Unnamed: 15
# 0         NaN
# 1         NaN
# ...
